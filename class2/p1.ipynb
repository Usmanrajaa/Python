# %% [markdown]
# ## 1. Assignment: assigning values to variables

# %%
a=5
b=6
c=9
# print(a,b,c)
# print(a)
# print(b)
# print(c)
a
b
c
# Out:
# 9

# %%
a=5;b=6;c=90

# %%
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 90

# %%
print(a);print(b);print(c)
# Out:
# 5
# 6
# 9

# %%
a=5
b=6
c=90

# %%
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 90

# %%
print(a,end=" ")
print(b,end=" ")
print(c,end=" ")
# Out:
# 5 6 90

# %%
print(a,"\n",b,"\n",c,"\n")
# Out:
# 5
#  6
#  90

# %%
x,y,t=45,(70,80),34

# %%
y
# Out:
# (70, 80)

# %%
a=b=c=d=30

# %%
print(a,b,c,d)
# Out:
# 30 30 30 30

# %%
g=5
h=8

# %%
g,h=h,g

# %%
g
# Out:
# 8

# %%
h
# Out:
# 5

# %%
u=60

# %%
u=80

# %%
u
# Out:
# 80
