# %% [markdown]
# ## Problem 1
# ### Take user input of 3 digit number then find out three following
# #### 1. Units digit
# #### 2. Tens digit
# #### 3. Hundreds digit
# ### then show summation of all three calculated stuffs

# %% [markdown]
# ## user input i.e 345 => unit digit=5, tens digit=4, hundreds digit=3,   o/p-> 5+4+3=12

# %%
a=int(input("enter your no:"))
print("number entered is:",a)
num1=a%10
print("for next digit calculation number",a//10)
a=a//10 
a ##34
num2=a%10  ##34%10=4

a=a//10  ##34=3
num3=a%10   ##3%10=3
print(num1+num2+num3)
# Out:
# number entered is: 345
# for next digit calculation number 34
# 12

# %%
a=345
a%10
# Out:
# 5
