# %% [markdown]
# ## Numpy Indexing

# %%
import numpy as np

# %%
arr=np.array([4,5,6,7,8,9])
arr[1]
# Out:
# np.int64(5)

# %%
arr_2d=np.array([[3,4,5],[4,5,9]])
arr_2d[0][2]
# Out:
# np.int64(5)

# %% [markdown]
# ## Numpy slicing

# %%
arr
# Out:
# array([4, 5, 6, 7, 8, 9])

# %%
arr[2:5]
# Out:
# array([6, 7, 8])
