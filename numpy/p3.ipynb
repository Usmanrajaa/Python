# %%
## NumPy practice problem

# take 5 input arrays where each array will be considered as a column so this way you have total 5 arrays. deliberately you have to take all 
# columns(arrays) of different data types(int,float,boolean,string,date). then you have to go for all the data cleaning/engineering part where , 
# first target is to convert all into proper numeric(int/float). then have to make table , i mean stack all columns so that a 2D table could be formed. 
# your previous practice of stacking and datatype conversions, and array creation etc. logic would be practices from this problem?

# %%
import numpy as np
