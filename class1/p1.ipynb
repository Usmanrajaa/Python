# %% [markdown]
# ## Python Print Statements

# %%
print("xyz")
# Out:
# xyz

# %%
print(45)
# Out:
# 45

# %%
x=45
print(x)
# Out:
# 45

# %%
y=30
print(y)
# Out:
# 30

# %%
print(x+y)
# Out:
# 75

# %%
print("abc","xyz","uvw",sep="-")
# Out:
# abc-xyz-uvw

# %%
print("abc",45,"uvw")
# Out:
# abc 45 uvw

# %%
print("i am neeraj \nand i ,have a special, characteristic \nthat should not be revealed")
# Out:
# i am neeraj
# and i ,have a special, characteristic
# that should not be revealed

# %%
x1="johnson"
x2=56
x3="John Smith"
print(x1,x2,x3,sep="-")
# Out:
# johnson-56-John Smith

# %%
print(f"my name is {x1},and i am {x2} year old, my friend name is {x3}")
# Out:
# my name is johnson,and i am 56 year old, my friend name is John Smith

# %%
a1="hello"
a2="world"

# %%
print(a1)
print(a2)
# Out:
# hello
# world

# %%
print(a1,end=" ")
print(a2)
# Out:
# hello world
