# %%
## open("file_name","mode")
f=open("practice1.txt","w")
f.write("hello guys , i am alex , a software developer at microsof \n")
f.write("my age is 50 years")
f.close()

# %%
f=open("practice1.txt","r")
f.read()
# Out:
# 'hello guys , i am alex , a software developer at microsof \nmy age is 50 years'

# %%
## make a table of 4 columns which has 
## employee_Name, salary, residence, company_name
## fill at least 5 rows data
