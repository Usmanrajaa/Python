# %% [markdown]
# ## ** Dictionary**

# %% [markdown]
# ## 1. Create

# %%
d1={"age":25,"profession":"sde","name":"harsh"}

# %%
d1
# Out:
# {'age': 25, 'profession': 'sde', 'name': 'alex'}

# %%
d2={"info":{"company_pincode":{"nort":56,"south":90},"board_count":90},"location":"north india","no. of companies":4555,"list1":[3,4,5,65]}

# %%
d2
# Out:
# {'info': {'company_pincode': {'nort': 56, 'south': 100}, 'board_count': 90},
#  'location': 'north india',
#  'no. of companies': 4555,
#  'list1': [3, 4, 5, 65]}

# %% [markdown]
# ## 2. access

# %%
d1['age']
# Out:
# 25

# %%
d2["info"]["company_pincode"]["south"]
# Out:
# 100

# %%
list(d2.keys())
# Out:
# ['info', 'location', 'no. of companies', 'list1']

# %%
list(d2.values())
# Out:
# [{'company_pincode': {'nort': 56, 'south': 120}, 'board_count': 90},
#  'north india',
#  4555,
#  [3, 4, 5, 65]]

# %%
list(d2.items())
# Out:
# [('info', {'company_pincode': {'nort': 56, 'south': 120}, 'board_count': 90}),
#  ('location', 'north india'),
#  ('no. of companies', 4555),
#  ('list1', [3, 4, 5, 65])]

# %%
for key,value in d2.items():
    print("key is: ",key, "->with value",value)
# Out:
# key is:  info ->with value {'company_pincode': {'nort': 56, 'south': 100}, 'board_count': 90}
# key is:  location ->with value north india
# key is:  no. of companies ->with value 4555
# key is:  list1 ->with value [3, 4, 5, 65]

# %%
# Out:
# 2 3
# 5 6

# %% [markdown]
# ## 3. Edit

# %%
d2["info"]["company_pincode"]["south"]
# Out:
# 100

# %%
d2["info"]["company_pincode"]["south"]=120

# %%
d2
# Out:
# {'info': {'company_pincode': {'nort': 56, 'south': 120}, 'board_count': 90},
#  'location': 'north india',
#  'no. of companies': 4555,
#  'list1': [3, 4, 5, 65]}

# %%
## dictionary comprehension

# %%
d5={x:x**2+3*x for x in range(1,10)}

# %%
d5
# Out:
# {1: 4, 2: 10, 3: 18, 4: 28, 5: 40, 6: 54, 7: 70, 8: 88, 9: 108}

# %%
list(d5.keys())
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
list(range(1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
d6={"a":"x","b":"y","c":"z"}
d6["d"]="m"
d6["e"]="n"

# %%
d6
# Out:
# {'a': 'x', 'b': 'y', 'c': 'z', 'd': 'm', 'e': 'n'}

# %%
d6.update({"f":"h","r":"w"})

# %%
d6
# Out:
# {'a': 'x', 'b': 'y', 'c': 'z', 'd': 'm', 'e': 'n', 'f': 'h', 'r': 'w'}
