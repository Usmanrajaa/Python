# %%
s1="hello"

# %%
s1[1]
# Out:
# 'e'

# %%
s1[1]="y"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s1[1]="y"
#
# TypeError: 'str' object does not support item assignment

# %%
s2="world"

# %%
s2.capitalize()
# Out:
# 'World'

# %%
s1+" "+s2
# Out:
# 'hello world'

# %%
len(s2)
# Out:
# 5

# %%
max(s2)
# Out:
# 'w'

# %%
"skillcircle is very supportive organization".endswith("p")
# Out:
# False

# %%
"skillcircle is very supportive organization".startswith("s")
# Out:
# True

# %%
l1=["p1.py","t1.txt","y1.csv","p2.py","p3.py","t2.txt","y2.csv"]
l2=[]
for i in l1:  ## element iteration 
    if i.endswith(".txt") or i.endswith(".py"):
        l2.append(i)
print(l2)
# Out:
# ['p1.py', 't1.txt', 'p2.py', 'p3.py', 't2.txt']

# %%
a="The world of data is epicenter of growth"
a.split()
# Out:
# ['The', 'world', 'of', 'data', 'is', 'epicenter', 'of', 'growth']

# %%
a="The world of data is epicenter of growth"
a.split("is")
# Out:
# ['The world of data ', ' epicenter of growth']

# %%
b=['the','world','of','data','is','epicencter','of','growth']
"-".join(b)
# Out:
# 'the-world-of-data-is-epicencter-of-growth'

# %%
c=['The world of data ', ' epicenter of growth']
"is".join(c)
# Out:
# 'The world of data is epicenter of growth'

# %%
d="The world of data is epicenter of growth"
d.replace("growth","progress")
# Out:
# 'The world of data is epicenter of progress'

# %%
e="     hello world   "
print(e.lstrip())
print(e.rstrip())
print(e.strip())
# Out:
# hello world
#      hello world
# hello world
