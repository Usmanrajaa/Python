# %% [markdown]
# ## SET
# ### 1. duplicates are not allowed
# ### 2. syntax=> {}
# ### 3. unordered
# ### 4. indexing not possible

# %% [markdown]
# ## 1. CREATE

# %%
s1={1,2,4,6,6,6,6,7}

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %%
## not allowed
## 2. Aceess  
## 3. EDIT

# %% [markdown]
# ## 4. add

# %%
s1.add(50)

# %%
s1
# Out:
# {1, 2, 4, 6, 7, 50}

# %%
s2={3,5,8}

# %% [markdown]
# ## 5. remove

# %%
s1.pop()
# Out:
# 1

# %%
s1.pop()
# Out:
# 2

# %%
s1.remove(6)

# %%
s1
# Out:
# {4, 7, 50}

# %% [markdown]
# ## 6. Operations

# %%
s1={4,5,5,6}
s2={9,8,2}

# %%
s1+s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s1+s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s1*3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %% [markdown]
# ## 7. functions

# %%
s1
# Out:
# {4, 5, 6, 9}

# %%
len(s1)
# Out:
# 4

# %%
max(s1)
# Out:
# 9

# %%
min(s1)
# Out:
# 4
