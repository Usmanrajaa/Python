# %% [markdown]
# ## TUPLES
# ### ordered
# ### immutable, once created the tuple later can't be modified
# ### duplicates allowed

# %% [markdown]
# ### 1. CREATE
# ### 2. ACCESS
# ### 3. EDIT
# ### 4. ADD
# ### 5. REMOVE
# ### 6. OPERATIONS
# ### 7. FUNCTIONS

# %% [markdown]
# ## 1. CREATE

# %%
t1=(2,3,4,5)
t1
# Out:
# (2, 3, 4, 5)

# %%
t2=(2,3,(5,6),8)
t2
# Out:
# (2, 3, (5, 6), 8)

# %%
t3=((2,3),(4,5),(6,8))
t3
# Out:
# ((2, 3), (4, 5), (6, 8))

# %% [markdown]
# ## 2. ACCESS

# %%
t4=(5,6,7,8,9)

# %%
t4[3]
# Out:
# 8

# %%
t4[2:5]
# Out:
# (7, 8, 9)

# %%
t4[-1]
# Out:
# 9

# %%
t4[::-1]
# Out:
# (9, 8, 7, 6, 5)

# %% [markdown]
# ## 3. EDIT

# %%
t4
# Out:
# (5, 6, 7, 8, 9)

# %%
t4[2]=56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t4[2]=56
#
# TypeError: 'tuple' object does not support item assignment

# %%
a=list(t4)
a
# Out:
# [5, 6, 7, 8, 9]

# %%
a[2]=45
a
tuple(a)
# Out:
# (5, 6, 45, 8, 9)

# %% [markdown]
# ## 4. ADD

# %%
t5=(5,6,7,8)
t6=(9,0,3,4)
t5+t6
# Out:
# (5, 6, 7, 8, 9, 0, 3, 4)

# %%
t5*3
# Out:
# (5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8)

# %%
print(6 in t5)
# Out:
# True

# %% [markdown]
# ## 5. DELETE

# %%
t5.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 t5.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t5.remove()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 t5.remove()
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t5.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 t5.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %% [markdown]
# ### 6. OPERATIONS

# %%
t5=(4,56,89,4,5,4,98,4)
t6=(4,)
print(t5)
print(t6)
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4)
# (4,)

# %%
t5+t6
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4, 4)

# %%
t5*2
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4, 4, 56, 89, 4, 5, 4, 98, 4)

# %% [markdown]
# ## 7. FUNCTIONS

# %%
min(t5)
# Out:
# 4

# %%
max(t5)
# Out:
# 98

# %%
len(t5)
# Out:
# 8

# %%
sorted(t5)
# Out:
# [4, 4, 4, 4, 5, 56, 89, 98]

# %%
sorted(t5,reverse=True)
# Out:
# [98, 89, 56, 5, 4, 4, 4, 4]

# %%
t5
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4)

# %%
t5.count(89)
# Out:
# 1
